# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates= list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d747a7dab2535c02549851e8d62b4c3

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
#Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          #"Date": city_date})
                          "Current Description":city_description,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | kahului
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | anadyr
# Processing Record 5 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | faanui
# Processing Record 8 of Set 1 | dalvik
# Processing Record 9 of Set 1 | san patricio
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | bambous virieux
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | clyde river
# Processing Record 15 of Set 1 | cherskiy
# Processing Record 16 of Set 1 | sedkyrkeshch
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | the valley
# Processing Record 21 of Set 1 | nanortalik
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | pemangkat
# Processing Record 24 of Set 1 | pevek
# Processing Record 25 of Set 1 | la ronge
# Processing Record 26 of Set 1 | fairbanks
# Processing Record 27 of Set 1 | sao joao da barra
# Processing Record 28 of Set 1 | iqaluit
# Processing Record 29 of Set 1 | sioux lookout
# Processing Record 30 of Set 1 | kaitangata
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | kasempa
# Processing Record 33 of Set 1 | belaya gora
# Processing Record 34 of Set 1 | kijang
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | port lincoln
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | denpasar
# Processing Record 39 of Set 1 | aniva
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | hamilton
# Processing Record 42 of Set 1 | lompoc
# Processing Record 43 of Set 1 | broome
# Processing Record 44 of Set 1 | yokadouma
# Processing Record 45 of Set 1 | katobu
# City not found. Skipping...
# Processing Record 46 of Set 1 | vardo
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | candolim
# Processing Record 49 of Set 1 | burnie
# Processing Record 50 of Set 1 | boulder city
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | sabang
# Processing Record 4 of Set 2 | port macquarie
# Processing Record 5 of Set 2 | nhulunbuy
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | upernavik
# Processing Record 8 of Set 2 | santa rosa
# Processing Record 9 of Set 2 | lasa
# Processing Record 10 of Set 2 | tual
# Processing Record 11 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 2 | svetlaya
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | urengoy
# Processing Record 15 of Set 2 | fortuna
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | padang
# Processing Record 18 of Set 2 | inuvik
# Processing Record 19 of Set 2 | faya
# Processing Record 20 of Set 2 | kakanj
# Processing Record 21 of Set 2 | alofi
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | mataura
# Processing Record 24 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 2 | mahebourg
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | kulu
# Processing Record 28 of Set 2 | guajara-mirim
# City not found. Skipping...
# Processing Record 29 of Set 2 | novoanninskiy
# Processing Record 30 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 2 | bluff
# Processing Record 32 of Set 2 | manzhouli
# Processing Record 33 of Set 2 | nadym
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | kandrian
# Processing Record 38 of Set 2 | srednekolymsk
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | ramhormoz
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | vila franca do campo
# Processing Record 43 of Set 2 | qaanaaq
# Processing Record 44 of Set 2 | fuyang
# Processing Record 45 of Set 2 | aklavik
# Processing Record 46 of Set 2 | sola
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | nouadhibou
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | pascagoula
# Processing Record 2 of Set 3 | avarua
# Processing Record 3 of Set 3 | salalah
# Processing Record 4 of Set 3 | gao
# Processing Record 5 of Set 3 | bethel
# Processing Record 6 of Set 3 | kashi
# Processing Record 7 of Set 3 | embonas
# Processing Record 8 of Set 3 | ketchikan
# Processing Record 9 of Set 3 | iguai
# Processing Record 10 of Set 3 | sabha
# Processing Record 11 of Set 3 | viedma
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | inyonga
# Processing Record 14 of Set 3 | russell
# Processing Record 15 of Set 3 | asyut
# Processing Record 16 of Set 3 | christchurch
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | nabire
# Processing Record 19 of Set 3 | kudahuvadhoo
# Processing Record 20 of Set 3 | katsuura
# Processing Record 21 of Set 3 | bihar
# Processing Record 22 of Set 3 | hofn
# Processing Record 23 of Set 3 | richards bay
# Processing Record 24 of Set 3 | nishihara
# Processing Record 25 of Set 3 | narsaq
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | saskylakh
# Processing Record 28 of Set 3 | kanniyakumari
# Processing Record 29 of Set 3 | guerrero negro
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | maningrida
# Processing Record 32 of Set 3 | hedaru
# Processing Record 33 of Set 3 | lancaster
# Processing Record 34 of Set 3 | bundoran
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | jabiru
# City not found. Skipping...
# Processing Record 37 of Set 3 | oxford
# Processing Record 38 of Set 3 | karratha
# Processing Record 39 of Set 3 | vyartsilya
# Processing Record 40 of Set 3 | bathsheba
# Processing Record 41 of Set 3 | castro
# Processing Record 42 of Set 3 | constitucion
# Processing Record 43 of Set 3 | athabasca
# Processing Record 44 of Set 3 | dauphin
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | chimore
# Processing Record 47 of Set 3 | urucara
# Processing Record 48 of Set 3 | ilulissat
# Processing Record 49 of Set 3 | dingle
# Processing Record 50 of Set 3 | salinopolis
# Processing Record 1 of Set 4 | klaksvik
# Processing Record 2 of Set 4 | ribeira grande
# Processing Record 3 of Set 4 | souillac
# Processing Record 4 of Set 4 | chuy
# Processing Record 5 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 4 | tessalit
# Processing Record 7 of Set 4 | mapiripan
# Processing Record 8 of Set 4 | davila
# Processing Record 9 of Set 4 | kruisfontein
# Processing Record 10 of Set 4 | vostok
# Processing Record 11 of Set 4 | nuuk
# Processing Record 12 of Set 4 | fare
# Processing Record 13 of Set 4 | beringovskiy
# Processing Record 14 of Set 4 | port hardy
# Processing Record 15 of Set 4 | zhangye
# Processing Record 16 of Set 4 | olinda
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | japura
# Processing Record 19 of Set 4 | bara
# Processing Record 20 of Set 4 | najran
# Processing Record 21 of Set 4 | saint anthony
# Processing Record 22 of Set 4 | huntington
# Processing Record 23 of Set 4 | mendi
# Processing Record 24 of Set 4 | shingu
# Processing Record 25 of Set 4 | tasiilaq
# Processing Record 26 of Set 4 | thompson
# Processing Record 27 of Set 4 | tazovskiy
# Processing Record 28 of Set 4 | bhunya
# Processing Record 29 of Set 4 | travesia
# Processing Record 30 of Set 4 | georgetown
# Processing Record 31 of Set 4 | nome
# Processing Record 32 of Set 4 | torbay
# Processing Record 33 of Set 4 | saint-philippe
# Processing Record 34 of Set 4 | wainwright
# Processing Record 35 of Set 4 | te anau
# Processing Record 36 of Set 4 | namibe
# Processing Record 37 of Set 4 | auki
# Processing Record 38 of Set 4 | huarmey
# Processing Record 39 of Set 4 | cabo san lucas
# Processing Record 40 of Set 4 | jonesboro
# Processing Record 41 of Set 4 | puri
# Processing Record 42 of Set 4 | provideniya
# Processing Record 43 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 4 | lorengau
# Processing Record 46 of Set 4 | isangel
# Processing Record 47 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 4 | toyooka
# Processing Record 49 of Set 4 | elizabeth city
# Processing Record 50 of Set 4 | kavieng
# Processing Record 1 of Set 5 | sitka
# Processing Record 2 of Set 5 | gat
# Processing Record 3 of Set 5 | primo tapia
# Processing Record 4 of Set 5 | mount isa
# Processing Record 5 of Set 5 | vilhena
# Processing Record 6 of Set 5 | diplo
# Processing Record 7 of Set 5 | saint-leu
# Processing Record 8 of Set 5 | meulaboh
# Processing Record 9 of Set 5 | safford
# Processing Record 10 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 5 | krasnoselkup
# Processing Record 12 of Set 5 | bereznik
# Processing Record 13 of Set 5 | okhotsk
# City not found. Skipping...
# Processing Record 14 of Set 5 | leningradskiy
# Processing Record 15 of Set 5 | sao tome
# Processing Record 16 of Set 5 | kupang
# Processing Record 17 of Set 5 | south lake tahoe
# Processing Record 18 of Set 5 | dikson
# Processing Record 19 of Set 5 | gazimurskiy zavod
# Processing Record 20 of Set 5 | cartagena
# Processing Record 21 of Set 5 | samarai
# Processing Record 22 of Set 5 | barrow
# Processing Record 23 of Set 5 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 24 of Set 5 | luanda
# Processing Record 25 of Set 5 | karaton
# Processing Record 26 of Set 5 | praia da vitoria
# Processing Record 27 of Set 5 | hambantota
# Processing Record 28 of Set 5 | roald
# Processing Record 29 of Set 5 | am timan
# Processing Record 30 of Set 5 | ushtobe
# Processing Record 31 of Set 5 | dickinson
# City not found. Skipping...
# Processing Record 32 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 5 | quelimane
# Processing Record 34 of Set 5 | wagar
# Processing Record 35 of Set 5 | esperance
# Processing Record 36 of Set 5 | sao filipe
# Processing Record 37 of Set 5 | santa cruz
# Processing Record 38 of Set 5 | hojai
# Processing Record 39 of Set 5 | walvis bay
# Processing Record 40 of Set 5 | airai
# Processing Record 41 of Set 5 | rio grande
# Processing Record 42 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 5 | hasaki
# Processing Record 44 of Set 5 | asau
# Processing Record 45 of Set 5 | hualmay
# Processing Record 46 of Set 5 | hami
# Processing Record 47 of Set 5 | formosa do rio preto
# Processing Record 48 of Set 5 | huaicheng
# Processing Record 49 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 50 of Set 5 | bengkulu
# Processing Record 1 of Set 6 | shakawe
# Processing Record 2 of Set 6 | gerash
# Processing Record 3 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 4 of Set 6 | mehran
# Processing Record 5 of Set 6 | cockburn town
# Processing Record 6 of Set 6 | xiaoweizhai
# Processing Record 7 of Set 6 | nantucket
# Processing Record 8 of Set 6 | maturin
# Processing Record 9 of Set 6 | oktyabrskoye
# Processing Record 10 of Set 6 | akdepe
# Processing Record 11 of Set 6 | byron bay
# Processing Record 12 of Set 6 | anju
# Processing Record 13 of Set 6 | barra dos coqueiros
# Processing Record 14 of Set 6 | pacific grove
# Processing Record 15 of Set 6 | coquimbo
# Processing Record 16 of Set 6 | ponta do sol
# Processing Record 17 of Set 6 | ancud
# Processing Record 18 of Set 6 | bekovo
# City not found. Skipping...
# Processing Record 19 of Set 6 | pangai
# Processing Record 20 of Set 6 | kendari
# Processing Record 21 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 6 | hermosillo
# Processing Record 23 of Set 6 | tuatapere
# Processing Record 24 of Set 6 | khuzhir
# Processing Record 25 of Set 6 | ko samui
# Processing Record 26 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 6 | kyaka
# Processing Record 28 of Set 6 | tilichiki
# Processing Record 29 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 6 | arraial do cabo
# Processing Record 31 of Set 6 | gari
# Processing Record 32 of Set 6 | dosso
# Processing Record 33 of Set 6 | sayansk
# Processing Record 34 of Set 6 | teknaf
# Processing Record 35 of Set 6 | buraydah
# Processing Record 36 of Set 6 | broken hill
# Processing Record 37 of Set 6 | cairns
# Processing Record 38 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 6 | isperih
# Processing Record 41 of Set 6 | alta floresta
# Processing Record 42 of Set 6 | puerto colombia
# Processing Record 43 of Set 6 | pointe-noire
# Processing Record 44 of Set 6 | boysun
# Processing Record 45 of Set 6 | touho
# Processing Record 46 of Set 6 | araouane
# City not found. Skipping...
# Processing Record 47 of Set 6 | mananjary
# Processing Record 48 of Set 6 | shahr-e babak
# Processing Record 49 of Set 6 | waingapu
# Processing Record 50 of Set 6 | sao sebastiao
# Processing Record 1 of Set 7 | manta
# Processing Record 2 of Set 7 | borsa
# Processing Record 3 of Set 7 | roma
# Processing Record 4 of Set 7 | ramgarh
# Processing Record 5 of Set 7 | kaseda
# Processing Record 6 of Set 7 | maple creek
# Processing Record 7 of Set 7 | saldanha
# Processing Record 8 of Set 7 | prince rupert
# Processing Record 9 of Set 7 | marsh harbour
# Processing Record 10 of Set 7 | port blair
# Processing Record 11 of Set 7 | poya
# Processing Record 12 of Set 7 | bilibino
# Processing Record 13 of Set 7 | moose factory
# Processing Record 14 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 7 | erie
# Processing Record 16 of Set 7 | coahuayana
# Processing Record 17 of Set 7 | omsukchan
# Processing Record 18 of Set 7 | ittre
# Processing Record 19 of Set 7 | launceston
# Processing Record 20 of Set 7 | kirakira
# Processing Record 21 of Set 7 | filingue
# Processing Record 22 of Set 7 | pangnirtung
# Processing Record 23 of Set 7 | paracuru
# City not found. Skipping...
# Processing Record 24 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 25 of Set 7 | luderitz
# Processing Record 26 of Set 7 | zonguldak
# Processing Record 27 of Set 7 | ascension
# Processing Record 28 of Set 7 | camacha
# Processing Record 29 of Set 7 | odweyne
# Processing Record 30 of Set 7 | deputatskiy
# Processing Record 31 of Set 7 | aberystwyth
# Processing Record 32 of Set 7 | kampot
# Processing Record 33 of Set 7 | greenfield
# Processing Record 34 of Set 7 | kalmunai
# Processing Record 35 of Set 7 | atambua
# Processing Record 36 of Set 7 | rabo de peixe
# Processing Record 37 of Set 7 | yar-sale
# Processing Record 38 of Set 7 | geraldton
# Processing Record 39 of Set 7 | nea playia
# Processing Record 40 of Set 7 | longyearbyen
# Processing Record 41 of Set 7 | kitui
# Processing Record 42 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 7 | dzaoudzi
# Processing Record 44 of Set 7 | lujan
# Processing Record 45 of Set 7 | hakui
# Processing Record 46 of Set 7 | half moon bay
# Processing Record 47 of Set 7 | letpadan
# Processing Record 48 of Set 7 | san pedro
# Processing Record 49 of Set 7 | kalanchak
# Processing Record 50 of Set 7 | aygut
# Processing Record 1 of Set 8 | stanger
# Processing Record 2 of Set 8 | horta
# Processing Record 3 of Set 8 | ishigaki
# Processing Record 4 of Set 8 | baruun-urt
# Processing Record 5 of Set 8 | agirish
# Processing Record 6 of Set 8 | bedele
# Processing Record 7 of Set 8 | noumea
# Processing Record 8 of Set 8 | diego de almagro
# Processing Record 9 of Set 8 | delta del tigre
# Processing Record 10 of Set 8 | caldwell
# Processing Record 11 of Set 8 | edd
# Processing Record 12 of Set 8 | seminole
# Processing Record 13 of Set 8 | anloga
# Processing Record 14 of Set 8 | coihaique
# Processing Record 15 of Set 8 | taormina
# Processing Record 16 of Set 8 | keuruu
# Processing Record 17 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 18 of Set 8 | payo
# Processing Record 19 of Set 8 | magdagachi
# Processing Record 20 of Set 8 | mayor pablo lagerenza
# Processing Record 21 of Set 8 | sao joao dos patos
# Processing Record 22 of Set 8 | flin flon
# Processing Record 23 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 24 of Set 8 | necochea
# Processing Record 25 of Set 8 | keshan
# City not found. Skipping...
# Processing Record 26 of Set 8 | laguna
# Processing Record 27 of Set 8 | koyilandi
# City not found. Skipping...
# Processing Record 28 of Set 8 | paraiso
# Processing Record 29 of Set 8 | paamiut
# Processing Record 30 of Set 8 | jacareacanga
# Processing Record 31 of Set 8 | egvekinot
# Processing Record 32 of Set 8 | dawson creek
# Processing Record 33 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 8 | itamarandiba
# Processing Record 35 of Set 8 | oume
# Processing Record 36 of Set 8 | stornoway
# Processing Record 37 of Set 8 | serenje
# Processing Record 38 of Set 8 | chumikan
# Processing Record 39 of Set 8 | pimentel
# Processing Record 40 of Set 8 | sug-aksy
# City not found. Skipping...
# Processing Record 41 of Set 8 | aporawan
# City not found. Skipping...
# Processing Record 42 of Set 8 | portland
# Processing Record 43 of Set 8 | salisbury
# Processing Record 44 of Set 8 | marfino
# Processing Record 45 of Set 8 | bonthe
# Processing Record 46 of Set 8 | ternate
# Processing Record 47 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 48 of Set 8 | yulara
# Processing Record 49 of Set 8 | kidal
# Processing Record 50 of Set 8 | la sarre
# Processing Record 1 of Set 9 | camopi
# Processing Record 2 of Set 9 | lebu
# Processing Record 3 of Set 9 | funtua
# Processing Record 4 of Set 9 | mutsu
# Processing Record 5 of Set 9 | dunedin
# Processing Record 6 of Set 9 | severo-kurilsk
# Processing Record 7 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 8 of Set 9 | jertih
# Processing Record 9 of Set 9 | rockland
# Processing Record 10 of Set 9 | cusuna
# Processing Record 11 of Set 9 | ilabaya
# Processing Record 12 of Set 9 | ribeira brava
# Processing Record 13 of Set 9 | tura
# Processing Record 14 of Set 9 | arlit
# Processing Record 15 of Set 9 | rawson
# Processing Record 16 of Set 9 | mondlo
# Processing Record 17 of Set 9 | vega de alatorre
# Processing Record 18 of Set 9 | mahendragarh
# Processing Record 19 of Set 9 | lagoa
# Processing Record 20 of Set 9 | fukue
# Processing Record 21 of Set 9 | kilindoni
# Processing Record 22 of Set 9 | dakar
# Processing Record 23 of Set 9 | caceres
# Processing Record 24 of Set 9 | port moresby
# Processing Record 25 of Set 9 | algiers
# Processing Record 26 of Set 9 | svetlogorsk
# Processing Record 27 of Set 9 | ferrol
# Processing Record 28 of Set 9 | listvyanka
# Processing Record 29 of Set 9 | zhanaozen
# Processing Record 30 of Set 9 | mabaruma
# Processing Record 31 of Set 9 | havelock
# Processing Record 32 of Set 9 | codrington
# Processing Record 33 of Set 9 | basco
# Processing Record 34 of Set 9 | lieto
# Processing Record 35 of Set 9 | kiama
# Processing Record 36 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 37 of Set 9 | ostrovnoy
# Processing Record 38 of Set 9 | goderich
# Processing Record 39 of Set 9 | kavaratti
# Processing Record 40 of Set 9 | trairi
# City not found. Skipping...
# Processing Record 41 of Set 9 | kapit
# Processing Record 42 of Set 9 | kibala
# Processing Record 43 of Set 9 | mahendranagar
# Processing Record 44 of Set 9 | los llanos de aridane
# Processing Record 45 of Set 9 | oranjemund
# Processing Record 46 of Set 9 | neya
# Processing Record 47 of Set 9 | rosarito
# Processing Record 48 of Set 9 | takhli
# Processing Record 49 of Set 9 | jackson
# Processing Record 50 of Set 9 | wladyslawowo
# Processing Record 1 of Set 10 | murwillumbah
# Processing Record 2 of Set 10 | eseka
# Processing Record 3 of Set 10 | rio gallegos
# Processing Record 4 of Set 10 | tikapur
# Processing Record 5 of Set 10 | floro
# Processing Record 6 of Set 10 | hyeres
# Processing Record 7 of Set 10 | manbij
# Processing Record 8 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 10 | homer
# Processing Record 10 of Set 10 | conde
# Processing Record 11 of Set 10 | guilin
# Processing Record 12 of Set 10 | dudinka
# Processing Record 13 of Set 10 | bodden town
# Processing Record 14 of Set 10 | van buren
# Processing Record 15 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 10 | zhigansk
# Processing Record 17 of Set 10 | galle
# Processing Record 18 of Set 10 | wajid
# Processing Record 19 of Set 10 | teya
# Processing Record 20 of Set 10 | hit
# Processing Record 21 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 10 | tautira
# Processing Record 23 of Set 10 | hukuntsi
# Processing Record 24 of Set 10 | lukovetskiy
# Processing Record 25 of Set 10 | tabuk
# Processing Record 26 of Set 10 | tukuran
# Processing Record 27 of Set 10 | pisco
# Processing Record 28 of Set 10 | lahij
# Processing Record 29 of Set 10 | sabirabad
# Processing Record 30 of Set 10 | chase
# Processing Record 31 of Set 10 | saquarema
# Processing Record 32 of Set 10 | sakakah
# Processing Record 33 of Set 10 | san jeronimo
# Processing Record 34 of Set 10 | haines junction
# Processing Record 35 of Set 10 | sorland
# Processing Record 36 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 37 of Set 10 | banda aceh
# Processing Record 38 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 10 | vrangel
# Processing Record 40 of Set 10 | tibiri
# Processing Record 41 of Set 10 | bojnurd
# Processing Record 42 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 10 | gushikawa
# Processing Record 44 of Set 10 | manyana
# Processing Record 45 of Set 10 | synya
# Processing Record 46 of Set 10 | payson
# Processing Record 47 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 48 of Set 10 | eyl
# Processing Record 49 of Set 10 | presidencia roque saenz pena
# Processing Record 50 of Set 10 | tucuma
# Processing Record 1 of Set 11 | marysville
# Processing Record 2 of Set 11 | mana
# Processing Record 3 of Set 11 | ejido
# Processing Record 4 of Set 11 | podor
# Processing Record 5 of Set 11 | isabela
# Processing Record 6 of Set 11 | ures
# Processing Record 7 of Set 11 | peniche
# Processing Record 8 of Set 11 | dhidhdhoo
# Processing Record 9 of Set 11 | menongue
# Processing Record 10 of Set 11 | taoudenni
# Processing Record 11 of Set 11 | hrubieszow
# Processing Record 12 of Set 11 | ban dung
# Processing Record 13 of Set 11 | lavrentiya
# Processing Record 14 of Set 11 | nobres
# Processing Record 15 of Set 11 | yerbogachen
# Processing Record 16 of Set 11 | quatre cocos
# Processing Record 17 of Set 11 | mnogovershinnyy
# Processing Record 18 of Set 11 | sopot
# Processing Record 19 of Set 11 | tandil
# Processing Record 20 of Set 11 | hay river
# Processing Record 21 of Set 11 | mazyr
# Processing Record 22 of Set 11 | hofgeismar
# Processing Record 23 of Set 11 | olafsvik
# Processing Record 24 of Set 11 | mollendo
# Processing Record 25 of Set 11 | marsa matruh
# Processing Record 26 of Set 11 | baijiantan
# Processing Record 27 of Set 11 | padampur
# Processing Record 28 of Set 11 | saint-joseph
# Processing Record 29 of Set 11 | bandarbeyla
# Processing Record 30 of Set 11 | yaan
# Processing Record 31 of Set 11 | sacramento
# Processing Record 32 of Set 11 | wukari
# Processing Record 33 of Set 11 | garowe
# Processing Record 34 of Set 11 | vallenar
# Processing Record 35 of Set 11 | komsomolskiy
# Processing Record 36 of Set 11 | iskateley
# Processing Record 37 of Set 11 | nizhniy baskunchak
# Processing Record 38 of Set 11 | tuy hoa
# Processing Record 39 of Set 11 | tutoia
# Processing Record 40 of Set 11 | auburn
# Processing Record 41 of Set 11 | namatanai
# Processing Record 42 of Set 11 | sinnamary
# Processing Record 43 of Set 11 | alekseyevsk
# Processing Record 44 of Set 11 | nardaran
# Processing Record 45 of Set 11 | sibu
# Processing Record 46 of Set 11 | nanakuli
# Processing Record 47 of Set 11 | ambilobe
# Processing Record 48 of Set 11 | beatrice
# Processing Record 49 of Set 11 | sri aman
# Processing Record 50 of Set 11 | mayumba
# Processing Record 1 of Set 12 | liku
# Processing Record 2 of Set 12 | ahipara
# Processing Record 3 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 4 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 12 | palu
# Processing Record 7 of Set 12 | uroteppa
# City not found. Skipping...
# Processing Record 8 of Set 12 | balkhash
# Processing Record 9 of Set 12 | jacmel
# Processing Record 10 of Set 12 | saint-pierre
# Processing Record 11 of Set 12 | korsakov
# Processing Record 12 of Set 12 | abha
# Processing Record 13 of Set 12 | zhangjiakou
# City not found. Skipping...
# Processing Record 14 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 12 | chapais
# Processing Record 16 of Set 12 | katete
# Processing Record 17 of Set 12 | catuday
# Processing Record 18 of Set 12 | dalby
# Processing Record 19 of Set 12 | nanyamba
# Processing Record 20 of Set 12 | thanatpin
# Processing Record 21 of Set 12 | vestmannaeyjar
# Processing Record 22 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 12 | loandjili
# Processing Record 24 of Set 12 | rupert
# Processing Record 25 of Set 12 | conceicao do araguaia
# Processing Record 26 of Set 12 | aykhal
# Processing Record 27 of Set 12 | jacobabad
# Processing Record 28 of Set 12 | dongsheng
# Processing Record 29 of Set 12 | ayan
# Processing Record 30 of Set 12 | pecos
# Processing Record 31 of Set 12 | kotovo
# Processing Record 32 of Set 12 | pasighat
# Processing Record 33 of Set 12 | gwadar
# Processing Record 34 of Set 12 | balasheyka
# Processing Record 35 of Set 12 | lom sak
# Processing Record 36 of Set 12 | korla
# Processing Record 37 of Set 12 | ukiah
# Processing Record 38 of Set 12 | nhamunda
# Processing Record 39 of Set 12 | palmer
# Processing Record 40 of Set 12 | shache
# Processing Record 41 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 12 | ritchie
# Processing Record 43 of Set 12 | san jose
# Processing Record 44 of Set 12 | pierre
# Processing Record 45 of Set 12 | batagay-alyta
# Processing Record 46 of Set 12 | henties bay
# Processing Record 47 of Set 12 | iracoubo
# Processing Record 48 of Set 12 | volkhov
# Processing Record 49 of Set 12 | pontianak
# Processing Record 50 of Set 12 | talnakh
# Processing Record 1 of Set 13 | ucluelet
# Processing Record 2 of Set 13 | evensk
# Processing Record 3 of Set 13 | waitati
# Processing Record 4 of Set 13 | itoman
# Processing Record 5 of Set 13 | harper
# Processing Record 6 of Set 13 | chipinge
# Processing Record 7 of Set 13 | charters towers
# Processing Record 8 of Set 13 | kaeo
# Processing Record 9 of Set 13 | qaqortoq
# Processing Record 10 of Set 13 | bolshaya glushitsa
# Processing Record 11 of Set 13 | korcula
# Processing Record 12 of Set 13 | vila velha
# Processing Record 13 of Set 13 | botucatu
# Processing Record 14 of Set 13 | muhoroni
# Processing Record 15 of Set 13 | carambei
# Processing Record 16 of Set 13 | wanlaweyn
# Processing Record 17 of Set 13 | luganville
# Processing Record 18 of Set 13 | sao jose da coroa grande
# Processing Record 19 of Set 13 | abong mbang
# Processing Record 20 of Set 13 | trang
# Processing Record 21 of Set 13 | beya
# Processing Record 22 of Set 13 | voyvozh
# Processing Record 23 of Set 13 | jining
# Processing Record 24 of Set 13 | clyde
# Processing Record 25 of Set 13 | lata
# Processing Record 26 of Set 13 | tecpan
# Processing Record 27 of Set 13 | quechultenango
# Processing Record 28 of Set 13 | hakvik
# City not found. Skipping...
# Processing Record 29 of Set 13 | kokopo
# Processing Record 30 of Set 13 | fort nelson
# Processing Record 31 of Set 13 | port angeles
# Processing Record 32 of Set 13 | calama
# Processing Record 33 of Set 13 | novosheshminsk
# City not found. Skipping...
# Processing Record 34 of Set 13 | baranain
# Processing Record 35 of Set 13 | ahuimanu
# Processing Record 36 of Set 13 | honiara
# Processing Record 37 of Set 13 | boyle
# Processing Record 38 of Set 13 | winston-salem
# Processing Record 39 of Set 13 | acapulco
# Processing Record 40 of Set 13 | lucea
# Processing Record 41 of Set 13 | cayenne
# Processing Record 42 of Set 13 | tiznit
# Processing Record 43 of Set 13 | yongan
# Processing Record 44 of Set 13 | salta
# Processing Record 45 of Set 13 | saint-denis
# Processing Record 46 of Set 13 | bushehr
# Processing Record 47 of Set 13 | verkh-usugli
# Processing Record 48 of Set 13 | ivybridge
# Processing Record 49 of Set 13 | wanaka
# Processing Record 50 of Set 13 | rovaniemi
# Processing Record 1 of Set 14 | montes altos
# Processing Record 2 of Set 14 | ulaangom
# Processing Record 3 of Set 14 | tankara
# Processing Record 4 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 14 | xam nua
# Processing Record 6 of Set 14 | mirnyy
# Processing Record 7 of Set 14 | santa helena
# Processing Record 8 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 14 | havre-saint-pierre
# Processing Record 10 of Set 14 | muros
# Processing Record 11 of Set 14 | naze
# Processing Record 12 of Set 14 | san blas
# Processing Record 13 of Set 14 | rajapur
# Processing Record 14 of Set 14 | port-gentil
# Processing Record 15 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 14 | pouso alegre
# Processing Record 17 of Set 14 | leshukonskoye
# Processing Record 18 of Set 14 | camargo
# Processing Record 19 of Set 14 | turtkul
# City not found. Skipping...
# Processing Record 20 of Set 14 | paramonga
# Processing Record 21 of Set 14 | kimberley
# Processing Record 22 of Set 14 | buta
# Processing Record 23 of Set 14 | marzuq
# Processing Record 24 of Set 14 | stege
# Processing Record 25 of Set 14 | charagua
# Processing Record 26 of Set 14 | manokwari
# Processing Record 27 of Set 14 | ugoofaaru
# Processing Record 28 of Set 14 | maridi
# Processing Record 29 of Set 14 | yumen
# Processing Record 30 of Set 14 | kuching
# Processing Record 31 of Set 14 | mogochin
# City not found. Skipping...
# Processing Record 32 of Set 14 | mehamn
# Processing Record 33 of Set 14 | santa maria
# Processing Record 34 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 14 | comrat
# Processing Record 36 of Set 14 | popondetta
# Processing Record 37 of Set 14 | atar
# Processing Record 38 of Set 14 | esil
# Processing Record 39 of Set 14 | mount gambier
# Processing Record 40 of Set 14 | sao jose de ribamar
# Processing Record 41 of Set 14 | taicheng
# Processing Record 42 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 43 of Set 14 | san rafael
# Processing Record 44 of Set 14 | tekari
# Processing Record 45 of Set 14 | hadejia
# Processing Record 46 of Set 14 | atasu
# Processing Record 47 of Set 14 | erenhot
# Processing Record 48 of Set 14 | carnduff
# Processing Record 49 of Set 14 | vao
# Processing Record 50 of Set 14 | ust-tsilma
# Processing Record 1 of Set 15 | oum hadjer
# Processing Record 2 of Set 15 | abu dhabi
# Processing Record 3 of Set 15 | amod
# Processing Record 4 of Set 15 | mandera
# Processing Record 5 of Set 15 | dukat
# Processing Record 6 of Set 15 | muriwai beach
# Processing Record 7 of Set 15 | maniitsoq
# Processing Record 8 of Set 15 | gijon
# Processing Record 9 of Set 15 | basay
# Processing Record 10 of Set 15 | puttur
# Processing Record 11 of Set 15 | olds
# Processing Record 12 of Set 15 | tomatlan
# Processing Record 13 of Set 15 | bubaque
# Processing Record 14 of Set 15 | chicama
# Processing Record 15 of Set 15 | khorixas
# Processing Record 16 of Set 15 | vila do maio
# Processing Record 17 of Set 15 | copacabana
# Processing Record 18 of Set 15 | morwa
# Processing Record 19 of Set 15 | novopokrovka
# Processing Record 20 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 15 | eureka
# Processing Record 22 of Set 15 | bandar-e lengeh
# Processing Record 23 of Set 15 | rocha
# Processing Record 24 of Set 15 | fereydun kenar
# Processing Record 25 of Set 15 | biu
# Processing Record 26 of Set 15 | mackenzie
# Processing Record 27 of Set 15 | san rafael del sur
# Processing Record 28 of Set 15 | kralendijk
# Processing Record 29 of Set 15 | tashtagol
# Processing Record 30 of Set 15 | tianmen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Punta Arenas -53.1500  -70.9167     55.11        62          75
# 1          Kahului  20.8947 -156.4700     75.85        73          40
# 2     Puerto Ayora  -0.7393  -90.3518     76.96        86         100
# 3           Anadyr  64.7500  177.4833      7.30        84          40
# 4           Faanui -16.4833 -151.7500     82.27        72         100
# 5           Dalvik  65.9702  -18.5286     41.22        80         100
# 6     San Patricio  28.0170  -97.5169     66.88        81          52
# 7      Tuktoyaktuk  69.4541 -133.0374    -11.79        91           5
# 8          Ushuaia -54.8000  -68.3000     60.46        44         100
# 9  Bambous Virieux -20.3428   57.7575     86.25        70          75
#
#    Wind Speed Country Current Description
# 0       11.50      CL       broken clouds
# 1       12.66      US    scattered clouds
# 2        5.19      EC          light rain
# 3        6.71      RU          light snow
# 4       12.37      PF     overcast clouds
# 5       16.69      IS     overcast clouds
# 6        7.65      US       broken clouds
# 7       11.61      CA           clear sky
# 8       26.46      AR     overcast clouds
# 9       11.50      MU       broken clouds

# %%
city_data_df=city_data_df[['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Punta Arenas      CL -53.1500  -70.9167     55.11        62          75
# 1          Kahului      US  20.8947 -156.4700     75.85        73          40
# 2     Puerto Ayora      EC  -0.7393  -90.3518     76.96        86         100
# 3           Anadyr      RU  64.7500  177.4833      7.30        84          40
# 4           Faanui      PF -16.4833 -151.7500     82.27        72         100
# 5           Dalvik      IS  65.9702  -18.5286     41.22        80         100
# 6     San Patricio      US  28.0170  -97.5169     66.88        81          52
# 7      Tuktoyaktuk      CA  69.4541 -133.0374    -11.79        91           5
# 8          Ushuaia      AR -54.8000  -68.3000     60.46        44         100
# 9  Bambous Virieux      MU -20.3428   57.7575     86.25        70          75
#
#    Wind Speed Current Description
# 0       11.50       broken clouds
# 1       12.66    scattered clouds
# 2        5.19          light rain
# 3        6.71          light snow
# 4       12.37     overcast clouds
# 5       16.69     overcast clouds
# 6        7.65       broken clouds
# 7       11.61           clear sky
# 8       26.46     overcast clouds
# 9       11.50       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Vacation_Search/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
